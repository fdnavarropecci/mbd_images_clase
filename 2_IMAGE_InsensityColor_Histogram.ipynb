# %%
###### FROM YOUR DESKTOP (LOCAL)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

##input_image = cv2.imread('drive/My Drive/Classroom/[ICAI] Master en Big Data -  Unstructured Data Analysis/IMAGE/images/wheel.png', cv2.IMREAD_GRAYSCALE)  # input_image: 2-dim array
img = cv2.imread(r"C:\Users\fdnav\mbd_images_clase\images\sea_beach.jpg")
print(img)
b, g, r = cv2.split(img)

cv2.imshow("img", img)
cv2.imshow("b", b)
cv2.imshow("g", g)
cv2.imshow("r", r)


plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])
plt.show()
# Out:
# [[[183  99  41]
#   [188 108  45]
#   [184 105  38]
#   ...
#   [135  54   3]
#   [131  50   0]
#   [129  48   0]]
#
#  [[181 100  33]
#   [184 105  38]
#   [182 103  36]
#   ...
#   [137  57   2]
#   [134  54   1]
#   [133  53   0]]
#
#  [[184 106  30]
#   [187 109  38]
#   [188 108  43]
#   ...
#   [140  59   2]
#   [137  57   2]
#   [137  57   2]]
#
#  ...
#
#  [[ 14  48  84]
#   [  6  43  77]
#   [ 21  62  95]
#   ...
#   [  0   4  29]
#   [  0   8  46]
#   [  4  11  54]]
#
#  [[  7  45  77]
#   [  2  42  71]
#   [ 13  57  86]
#   ...
#   [  7  17  51]
#   [  7  11  52]
#   [  4  15  53]]
#
#  [[  3  48  75]
#   [  6  50  81]
#   [  2  44  79]
#   ...
#   [  0   9  46]
#   [  5  17  53]
#   [  0  13  39]]]

# %%
####### FROM GOOGLE COLABORATORY

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/DOCENCIA_Universidad_CLASSROOM/[ICAI] Master en Big Data - Unstructured Data Analysis/IMAGE/images/"
# Out:
# 3_the_book_thief.jpg  ioi2.jpg		   river2.jpg
# apink.jpg	      ioi.jpg		   sea_beach.jpg
# beaver.png	      kidman-cruise.jpg    the_book_thief.jpg
# beaver_xform.png      Lenna.png		   track.jpg
# box_in_scene.png      logo.jpg		   wheel.png
# box.png		      me_holding_book.jpg  xfiles.jpg
# dragonfly.jpg	      messi.jpg		   xfiles_result.png
# drawing.png	      river1.jpg

# %%
import os, sys 
from google.colab.patches import cv2_imshow

os.chdir("/content/drive/My Drive/DOCENCIA_Universidad_CLASSROOM/[ICAI] Master en Big Data - Unstructured Data Analysis/IMAGE") 
sys.path.append("/content/drive/My Drive/DOCENCIA_Universidad_CLASSROOM/[ICAI] Master en Big Data - Unstructured Data Analysis/IMAGE") 
    
# Root directory of the project 
ROOT_DIR = os.path.abspath(".") 
# Directory of images to run detection on 
IMAGE_DIR = os.path.join(ROOT_DIR, "images") 

img = cv2.imread(os.path.join(IMAGE_DIR, "sea_beach.jpg"))
print(img)
b, g, r = cv2.split(img)



plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])
plt.show()

plt.imshow(img)
# Out:
# [[[183  99  41]
#   [188 108  45]
#   [184 105  38]
#   ...
#   [135  54   3]
#   [131  50   0]
#   [129  48   0]]
#
#  [[181 100  33]
#   [184 105  38]
#   [182 103  36]
#   ...
#   [137  57   2]
#   [134  54   1]
#   [133  53   0]]
#
#  [[184 106  30]
#   [187 109  38]
#   [188 108  43]
#   ...
#   [140  59   2]
#   [137  57   2]
#   [137  57   2]]
#
#  ...
#
#  [[ 14  48  84]
#   [  6  43  77]
#   [ 21  62  95]
#   ...
#   [  0   4  29]
#   [  0   8  46]
#   [  4  11  54]]
#
#  [[  7  45  77]
#   [  2  42  71]
#   [ 13  57  86]
#   ...
#   [  7  17  51]
#   [  7  11  52]
#   [  4  15  53]]
#
#  [[  3  48  75]
#   [  6  50  81]
#   [  2  44  79]
#   ...
#   [  0   9  46]
#   [  5  17  53]
#   [  0  13  39]]]

# %%
#YOUR TURN
# Change the picture 
# TRY a balck and white photo too 
##input_image = cv2.imread('drive/My Drive/Classroom/[ICAI] Master en Big Data -  Unstructured Data Analysis/IMAGE/images/wheel.png', cv2.IMREAD_GRAYSCALE)  # input_image: 2-dim array
img = cv2.imread(r"C:\Users\fdnav\mbd_images_clase\images\beaver.png")
print(img)
b, g, r = cv2.split(img)

cv2.imshow("img", img)
cv2.imshow("b", b)
cv2.imshow("g", g)
cv2.imshow("r", r)


plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])
plt.show()
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]]
